# %% [markdown]
# #### Find the intersections of two functions $g_1(x) = sin(x)$ and $g_2(x) = 1 - x^2$

# %%
import numpy as np
import matplotlib as plt

# %%
x = np.linspace(-8, 8, 10000)
def g1(x):
    return np.sin(x)
def g2(x):
    return (1 - x*x)

# %%
plot(x, g1(x))
plot(x, g2(x))

# %%
g2(10)
# Out:
# -99

# %%
plot?
