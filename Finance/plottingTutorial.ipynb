# %%
import matplotlib.pyplot as pl
x = linspace(0,5,10)
y = x ** 2

# %%
figure()
plot(x,y,'r')
xlabel('x')
ylabel('y')
title('title')
show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-c89539b9911b> in <module>()
# ----> 1 figure()
#       2 plot(x,y,'r')
#       3 xlabel('x')
#       4 ylabel('y')
#       5 title('title')
#
# TypeError: 'Figure' object is not callable

# %%
subplot(1,2,1)
plot(x,y, 'r--')
subplot(1,2,2)
plot(y,x, 'g*-');

# %%
x = linspace(0,2*pi,500)
y = sin(x)/cos(x)
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes.plot(x,y,'r')

axes.set_xlabel('x')
axes.set_ylabel( "sin(x)/cos(x)")
axes.set_title("graphing shit")

# %%
y = log(x)
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5, 0.4, 0.3])

axes1.plot(x,y,'g')
axes1.set_xlabel('x')
axes1.set_ylabel('y')
axes1.set_title('title')


axes2.plot(y,x,'g')

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %% [markdown]
# # Surface Plots

# %%
alpha = 0.7
phi_ext = 2 * pi * 0.5

def flux_qubit_potential(phi_m, phi_p):
    return 2 + alpha - 2 * cos(phi_p)*cos(phi_m) - alpha * cos(phi_ext - 2*phi_p)

phi_m = linspace(0, 2*pi, 100)
phi_p = linspace(0, 2*pi, 100)
X,Y = meshgrid(phi_p, phi_m)
Z = flux_qubit_potential(X, Y).T


fit = plt.figure(figsize=(14,6))

ax = fig.add_subplot(1,2,1, projection='3d')

p = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm, linewidth=0, antialiased=False)
cb = fig.colorbar(p, shrink=0.5)

# %%
fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(1, 1, 1, projection='3d')


p = ax.plot_wireframe(X, Y, Z, rstride=4, cstride=4)

# %%
x = linspace(1,10,50)
y = linspace(1,10,50)
[x,y] = meshgrid(x,y)
z = sqrt(x) + sqrt(y)
print type(x)
print type(z)
figu = plt.figure(figsize =(8,6))
aks = Axes3D(figu)
aks.plot_wireframe(x, y, z)
# Out:
# <type 'numpy.ndarray'>
# <type 'numpy.ndarray'>

# %%
a = [0,1,2]
b = [1,2,3]
c = meshgrid(a,b)

# %%
import pyuvvis
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-97-2dc9322897be> in <module>()
# ----> 1 import pyuvvis
#
# ImportError: No module named pyuvvis
