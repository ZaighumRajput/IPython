# %% [raw]
# Checking if stochastic scenarios are risk-neutral

# %%
import pandas as pd
import os
import matplotlib as plt
import numpy as np

# %%
os.chdir("C:\MCPPI Data\\201406_2")

# %%
stocJun30_2 = pd.read_csv("mcppi_Stochastic_Jun30_2.csv", index_col="TimeStep")

# %%
stocJun30_2LogReturns = np.log(stocJun30_2["FundNAV"] /stocJun30_2["FundNAV"].shift(1))

# %%
stocJun30_2LogReturns
# Out:
#           ScenNo   FundNAV
# TimeStep
# 0.000000     NaN       NaN
# 0.003968       0 -0.001611
# 0.007936       0  0.001121
# 0.011905       0 -0.000681
# 0.015873       0 -0.003319
# 0.019841       0  0.001987
# 0.023810       0 -0.000391
# 0.027778       0 -0.001556
# 0.031746       0 -0.000020
# 0.035714       0 -0.000402
# 0.039683       0 -0.001468
# 0.043651       0 -0.002055
# 0.047619       0  0.004859
# 0.051587       0 -0.005071
# 0.055556       0  0.005663
# 0.059524       0 -0.002159
# 0.063492       0  0.001567
# 0.067460       0 -0.011192
# 0.071429       0 -0.003925
# 0.075397       0  0.002635
# 0.079365       0  0.007814
# 0.083333       0 -0.001847
# 0.087302       0  0.003298
# 0.091270       0  0.007652
# 0.095238       0  0.006969
# 0.099206       0 -0.010292
# 0.103170       0 -0.002539
# 0.107140       0 -0.000784
# 0.111110       0  0.012225
# 0.115080       0 -0.006179
# 0.119050       0 -0.004027
# 0.123020       0  0.005825
# 0.126980       0 -0.000100
# ...

# %%
#stocJun30_2LogReturns[stocJun30_2LogReturns["ScenNo"] == 1]
stocJun30_2[stocJun30_2["ScenNo"] == 156].plot(use_index = True, y = "FundNAV")

#stocJun30[stocJun30["ScenNo"] == 156]
